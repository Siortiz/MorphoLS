# %% [markdown]
# # Studing the enviroment of the galaxies

# %% [markdown]
# ## Downloading this notebook example
#
#
# This notebook can be downloaded in this [link](
# https://gitlab.com/joseaher/astromorphlib/-/raw/main/docs/notebooks/Enviroment-search.ipynb?ref_type=heads&inline=false)

# %% [markdown]
# ## Loading libraries

# %%
import stat_lib as SL

# %% [markdown]
# __command to unable the cell scroll__

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) { return false; }

# %% [markdown]
# ## The Hydra BCG  (NGC3311) enviroment within a box of 500kpc

# %% [markdown]
# See the full explication of the parameters of simbad_thumbnail() [here](https://astromorphlib.readthedocs.io/en/latest/pars/simbad-thumbnail.html)

# %%
SL.simbad_thumbnail('ngc3311', 'simbad', 
                    size_image_phy=100,
                    limtvel=500)
# Out:
# Basic information:
# -------------------
# RA  = 159.178421
# DEC = -27.528339
# Rad Vel = 3858.0 km/s
# Distance = 55.1 Mpc
#
#
# Dowloading fits_images/ngc3311_simbad_100kpc.fits ...
#
# The folder "fits_images" was created
#
# The folder "images was" created
#
# This images/ngc3311_simbad_100kpc.png file is already downloaded...
#
# ------------------------
#
# Simbad query
# ...
#
# region(circle, 159.178421d -27.528339d, 374s) & radvel  < 4358.0 & radvel > 3358.0 & Otypes = G & maintype != GlobCluster_Candidate
#
# Output
# ...
#
#         MAIN_ID             RA_d     ...     RVZ_BIBCODE     SCRIPT_NUMBER_ID
#                             deg      ...
# ----------------------- ------------ ... ------------------- ----------------
#            LEDA  141484 159.17824000 ... 2004AJ....128.1558S                0
#            [MMH2011] 66 159.16242000 ... 2011A&A...531A...4M                0
#         [WH2007] UCD 23 159.21175000 ... 2011A&A...531A...4M                0
# ...

# %% [markdown]
# ## The M51 enviroment within a box of 100kpc

# %%
SL.simbad_thumbnail('m51','simbad', 
                    size_image_phy=100,
                    limtvel=500)
# Out:
# Basic information:
# -------------------
# Galaxy Name: m51
# MAIN_ID: M  51
# RA  = 202.469575
# DEC = 47.195258
# Rad Vel = 465.0 km/s
# Distance = 6.6 Mpc
#
#
# This fits_images/m51_simbad_100kpc.fits file is already downloaded...
#
# ------------------------
#
# Simbad query
# ...
#
# region(circle, 202.469575d +47.195258d, 3105s) & radvel  < 965.0 & radvel > -35.0 & Otypes = G & maintype != GlobCluster_Candidate
#
# Output
# ...
#
#  MAIN_ID      RA_d        DEC_d     ...     RVZ_BIBCODE     SCRIPT_NUMBER_ID
#               deg          deg      ...
# --------- ------------ ------------ ... ------------------- ----------------
# NGC  5195 202.49829200  47.26612800 ... 1999PASP..111..438F                0
#     M  51 202.46957500  47.19525800 ... 1999PASP..111..438F                0
#
#
# Projected Distances
# ------------------------
# Proyected distance m51 and (0) NGC  5195 (571.0 km/s) is = 8.5\,kpc (264.6$\arcsec$)
# ...
